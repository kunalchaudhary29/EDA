# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Inclass - Lab <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Adult Income Data)
#
# The dataset contains information about the individuals' age, gender, and several attributes affecting the income of a person. <br> Attribute information:
#
# **age:** Age of an individual
#
# **workclass:** Working class of the individual
#
# **fnlwgt:** Weights based on the demographic characteristics
#
# **education:** Highest education of the individual
#
# **education.num:** Education encoded with unique numbers
#
# **marital.status:** Marital status of the individual
#
# **occupation:** Occupation of the individual
#
# **relationship:** Relation of the individual in the family
#
# **race:** Race of the individual
#
# **sex:** Gender of the individual
#
# **capital.gain:** Gain amount of the individual
#
# **capital.loss:** Loss amount of the individual
#
# **hours.per.week:** Working hours per week
#
# **native.country:** The native country of the individual
#
# **income:** Income of the individual

# %% [markdown]
# ##  Table of Content
#
# 1. **[Quantitative and Quantitative Analysis](#quan)**
# 2. **[Categorical and Quantitative Analysis](#catquan)**
# 3. **[Categorical and Categorical Analysis](#cat)**

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the adult dataset and check the first five observations

# %%
# type your code here
df_adult=pd.read_csv('adult.csv')
df_adult.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90         ?   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66         ?  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                  ?  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                  ?      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# 1          4356              18  United-States  <=50K
# 2          4356              40  United-States  <=50K
# 3          3900              40  United-States  <=50K
# 4          3900              40  United-States  <=50K

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <a id="quan"> </a>
# ## 1. Quantitative and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. Is there any effect of a person's age on the working hours</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(15,8))
sns.scatterplot(x=df_adult['age'],y=df_adult['hours.per.week'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Analyze the trend of the capital gain amount for different educational qualifications</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_adult[['capital.gain','education.num']].groupby('education.num').mean().plot(figsize=(15,8))
# Out:
# <Axes: xlabel='education.num'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Check the effect of working hours of individuals on capital gain </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(x=df_adult['hours.per.week'],y=df_adult['capital.gain'])
# Out:
# <Axes: xlabel='hours.per.week', ylabel='capital.gain'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4.  Find the trend in the average working hours corresponding to the age of an individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_adult[['age','hours.per.week']].groupby(['age']).mean().plot(figsize=(15,8))
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Check the distribution of the average capital loss corresponding to the age</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_adult[['age','capital.loss']].groupby('age').mean().plot(figsize=(15,8))
# Out:
# <Axes: xlabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is there a negative relation between capital gain and age?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.scatterplot(x=df_adult['age'],y=df_adult['capital.gain'])
# Out:
# <Axes: xlabel='age', ylabel='capital.gain'>

# %% [markdown]
# <a id="catquan"> </a>
# ## 2. Categorical and Quantitative Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Compare the average age with levels of income </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
average_age_by_income=df_adult.groupby('income')['age'].mean()
average_age_by_income.plot(kind="bar",color='blue')
plt.title('Average Age  Vs Income')
plt.xlabel('Income')
plt.ylabel('Average Age')
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Check the distribution of working hours with respect to the gender of the individual</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.violinplot(x=df_adult['sex'],y=df_adult['hours.per.week'],color='red')
# Out:
# <Axes: xlabel='sex', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Compare the income of individuals based on their education</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.violinplot(x=df_adult['income'],y=df_adult['education.num'],color='black')
# Out:
# <Axes: xlabel='income', ylabel='education.num'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the average age of males and females</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
average_age=df_adult.groupby('sex')['age'].mean()
# sns.barplot(x=df_adult['sex'],y=df_adult['average_age'],color='red')
average_age.plot(kind='bar',color='red')
# Out:
# <Axes: xlabel='sex'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>11. Compare the distribution of working hours for the distinct classes of income
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(x=df_adult['income'],y=df_adult['hours.per.week'])
plt.show()

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>12. Identify the positively skewed distributions of age based on the gender and race of the individual
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.violinplot(x=df_adult['race'],y=df_adult['age'],hue=df_adult['sex'],split=True)
# Out:
# <Axes: xlabel='race', ylabel='age'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>13. Compare the working hours for each working class</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(15,8))
sns.boxplot(x=df_adult['workclass'],y=df_adult['hours.per.week'])
# Out:
# <Axes: xlabel='workclass', ylabel='hours.per.week'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>14. Compare the weightage based on demographic characteristics by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
sns.boxplot(x=df_adult['sex'],y=df_adult['fnlwgt'])
# Out:
# <Axes: xlabel='sex', ylabel='fnlwgt'>

# %% [markdown]
# <a id="cat"> </a>
# ## 3. Categorical and Categorical Analysis

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>15. Study the variation in income by gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
income_table=pd.crosstab(index=df_adult["sex"],columns=df_adult["income"])
income_table
# Out:
# income  <=50K  >50K
# sex
# Female   9592  1179
# Male    15128  6662

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>16. Compare the income by race</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
income_table=pd.crosstab(index=df_adult["income"],columns=df_adult["race"])
income_table
# Out:
# race    Amer-Indian-Eskimo  Asian-Pac-Islander  Black  Other  White
# income
# <=50K                  275                 763   2737    246  20699
# >50K                    36                 276    387     25   7117

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>17. Is there an all male profession according to the data?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
income_table=pd.crosstab(index=df_adult["sex"],columns=df_adult["occupation"])
# income_table[income_table.loc['female']==0]
val=income_table[(income_table['Female']==0)]
print(val)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\_libs\index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Female'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# e:\EDA WEEK 1\EDA - In-Class Lab Exercise (Day 3) - Questions [v1.0 - 270320].ipynb Cell 45 line 4
#       <a href='vscode-notebook-cell:/e%3A/EDA%20WEEK%201/EDA%20-%20In-Class%20Lab%20Exercise%20%28Day%203%29%20-%20Questions%20%5Bv1.0%20-%20270320%5D.ipynb#X62sZmlsZQ%3D%3D?line=1'>2</a> income_table=pd.crosstab(index=df_adult["sex"],columns=df_adult["occupation"])
#       <a href='vscode-notebook-cell:/e%3A/EDA%20WEEK%201/EDA%20-%20In-Class%20Lab%20Exercise%20%28Day%203%29%20-%20Questions%20%5Bv1.0%20-%20270320%5D.ipynb#X62sZmlsZQ%3D%3D?line=2'>3</a> # income_table[income_table.loc['female']==0]
# ----> <a href='vscode-notebook-cell:/e%3A/EDA%20WEEK%201/EDA%20-%20In-Class%20Lab%20Exercise%20%28Day%203%29%20-%20Questions%20%5Bv1.0%20-%20270320%5D.ipynb#X62sZmlsZQ%3D%3D?line=3'>4</a> val=income_table[(income_table['Female']==0)]
#       <a href='vscode-notebook-cell:/e%3A/EDA%20WEEK%201/EDA%20-%20In-Class%20Lab%20Exercise%20%28Day%203%29%20-%20Questions%20%5Bv1.0%20-%20270320%5D.ipynb#X62sZmlsZQ%3D%3D?line=4'>5</a> print(val)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:3761, in DataFrame.__getitem__(self, key)
#    3759 if self.columns.nlevels > 1:
#    3760     return self._getitem_multilevel(key)
# -> 3761 indexer = self.columns.get_loc(key)
#    3762 if is_integer(indexer):
#    3763     indexer = [indexer]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\indexes\base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'Female'

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>18. How does income vary with working class?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.pivot_table(data=df_adult,index='workclass',columns='income',values='age',aggfunc='mean')
# Out:
# income                <=50K       >50K
# workclass
# ?                 39.258359  55.617801
# Federal-gov       40.624788  45.711590
# Local-gov         40.704607  44.254457
# Never-worked      20.571429        NaN
# Private           35.113404  42.815233
# Self-emp-inc      43.206478  48.249196
# Self-emp-not-inc  44.388553  46.428177
# State-gov         37.279365  45.209632
# Without-pay       47.785714        NaN

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>19. How is income related to marital status?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(index=df_adult['income'],columns=df_adult['marital.status'])
# Out:
# marital.status  Divorced  Married-AF-spouse  Married-civ-spouse  \
# income
# <=50K               3980                 13                8284
# >50K                 463                 10                6692
#
# marital.status  Married-spouse-absent  Never-married  Separated  Widowed
# income
# <=50K                             384          10192        959      908
# >50K                               34            491         66       85

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>20. Compare the income for different occupations</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
pd.crosstab(index=df_adult['income'],columns=df_adult['occupation'])
# Out:
# occupation     ?  Adm-clerical  Armed-Forces  Craft-repair  Exec-managerial  \
# income
# <=50K       1652          3263             8          3170             2098
# >50K         191           507             1           929             1968
#
# occupation  Farming-fishing  Handlers-cleaners  Machine-op-inspct  \
# income
# <=50K                   879               1284               1752
# >50K                    115                 86                250
#
# occupation  Other-service  Priv-house-serv  Prof-specialty  Protective-serv  \
# income
# <=50K                3158              148            2281              438
# >50K                  137                1            1859              211
#
# occupation  Sales  Tech-support  Transport-moving
# income
# <=50K        2667           645              1277
# >50K          983           283               320
