# %% [markdown]
# <table align="center" width=100%>
#     <tr>
#         <td width="20%">
#             <img src="GL-2.png">
#         </td>
#         <td>
#             <div align="center">
#                 <font color="#21618C" size=8px>
#                     <b> Take-Home <br>(Day 3)
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ### About the dataset (Customer Tip Data)
#
# The dataset contains information about the 244 orders served at a restaurant in the United States. Each observation includes the factors related to the order like total bill, time, the total number of people in a group, gender of the person paying for the order and so on.
#
# Attribute Information:
#
# **total_bill:** Total bill (cost of the meal), including tax, in US dollars
#
# **tip:** Tip in US dollars
#
# **sex:** Sex of person paying for the meal
#
# **smoker:** There is a smoker in a group or not
#
# **day:** Day on which the order is served
#
# **time:** Time of the order
#
# **size:** Size of the group

# %% [markdown]
# **Import the required libraries**

# %%
# type your code here
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the customer tip dataset and print the first five observations

# %%
# type your code here
df_customer=pd.read_csv('customer_tip.csv')
df_customer.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# ### Let's begin with some hands-on practice exercises

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>1. What is the percentage of males and females in the dataset? and display it in the plot</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
df_customer['sex'].value_counts()/len(df_customer)*100
# Out:
# sex
# Male      64.344262
# Female    35.655738
# Name: count, dtype: float64

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>2. Is there any relationship between tip and total bill amount? Support your answer with a plot
#  </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
val=df_customer['tip'].corr(df_customer['total_bill'])
print(val)

plt.figure(figsize=(10,6))
plt.scatter(x=df_customer['tip'],y=df_customer['total_bill'],color='red',label='data points',marker='o')

plt.xlabel('Tip')
plt.ylabel('Total Bill')
plt.grid(True)
plt.title('Tip vs Total Bill')
# Out:
# 0.6757341092113643
# Text(0.5, 1.0, 'Tip vs Total Bill')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>3. Which is the busiest day and time at the restaurant?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
day_time_counts=df_customer.groupby(['day','time']).size().reset_index(name='Count')
print(day_time_counts)
val=day_time_counts.sort_values(by='Count',ascending=False).head(1)
print('Busiest Day:',val.iloc[0]['day'])
print('Busiest Time:',val.iloc[0]['time'])
# Out:
#     day    time  Count
# 0   Fri  Dinner     12
# 1   Fri   Lunch      7
# 2   Sat  Dinner     87
# 3   Sun  Dinner     76
# 4  Thur  Dinner      1
# 5  Thur   Lunch     61
# Busiest Day: Sat
# Busiest Time: Dinner

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>4. Compute the gender-wise count based on smoking habits</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
gender_smoking=df_customer.groupby(['sex','smoker']).size().reset_index(name='count')
print(gender_smoking)
# Out:
#       sex smoker  count
# 0  Female     No     54
# 1  Female    Yes     33
# 2    Male     No     97
# 3    Male    Yes     60

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>5. Compare the tip amount given for different days
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
total_amount_tip_by_days=df_customer.groupby('day')['tip'].sum()
print(total_amount_tip_by_days)
total_amount_tip_by_days.plot(kind='bar',color='red')
plt.title('Tip Amount vs Day')
plt.ylabel('Total Tip')
# Out:
# day
# Fri      51.96
# Sat     260.40
# Sun     247.39
# Thur    171.83
# Name: tip, dtype: float64
# Text(0, 0.5, 'Total Tip')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>6. Is the average bill amount dependent on the size of the group?
# </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
val=df_customer['size'].corr(df_customer['total_bill'])
print(val)

plt.figure(figsize=(10,5))
plt.scatter(x=df_customer['size'],y=df_customer['total_bill'],color='red',label='Data Points')
plt.title('Total Bill vs Group Size')
plt.xlabel('Group Size')
plt.ylabel('Total Bill')
plt.show()
# Out:
# 0.5983151309049018

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>7. Is the tip amount varying based on gender and time?</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(8,6))
sns.violinplot(x=df_customer['sex'],y=df_customer['tip'],hue=df_customer['time'],split=True)
# Out:
# <Axes: xlabel='sex', ylabel='tip'>

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>8. Visualize the average bill amount for each day</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
average_bill_per_day=df_customer.groupby('day')['total_bill'].mean()
print(average_bill_per_day)

average_bill_per_day.plot(kind='bar',color='green')

plt.title('Total Bill Average vs Day')
plt.ylabel('Average Bill Amount')
# Out:
# day
# Fri     17.151579
# Sat     20.441379
# Sun     21.410000
# Thur    17.682742
# Name: total_bill, dtype: float64
# Text(0, 0.5, 'Average Bill Amount')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>9. Plot a horizontal boxplot to compare the bill amount based on gender</b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
plt.figure(figsize=(8,5))
sns.boxplot(x=df_customer['total_bill'],y=df_customer['sex'])
plt.title('Amount vs Sex')
plt.ylabel('Gender')
plt.xlabel('Total Bill')
# Out:
# Text(0.5, 0, 'Total Bill')

# %% [markdown]
# <table align="left">
#     <tr>
#         <td width="6%">
#             <img src="question_icon.png">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b>10. Find the maximum bill amount for lunch and dinner on Saturday and Sunday </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>

# %%
# type your code here
filtered_data = df_customer[(df_customer['day'].isin(['Sat', 'Sun'])) & (df_customer['time'].isin(['Lunch', 'Dinner']))]
print(filtered_data)
val=filtered_data.groupby(['day','time'])['total_bill'].max()
print(val)
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 238       35.83  4.67  Female     No  Sat  Dinner     3
# 239       29.03  5.92    Male     No  Sat  Dinner     3
# 240       27.18  2.00  Female    Yes  Sat  Dinner     2
# 241       22.67  2.00    Male    Yes  Sat  Dinner     2
# 242       17.82  1.75    Male     No  Sat  Dinner     2
#
# [163 rows x 7 columns]
# day  time
# Sat  Dinner    50.81
# Sun  Dinner    48.17
# Name: total_bill, dtype: float64
