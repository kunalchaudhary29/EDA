# %%
import seaborn as sns
import numpy as np
import pandas as pd
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
from pylab import rcParams

import warnings 
warnings.filterwarnings('ignore')

# %%
from IPython.display import Image
Image(filename='Univariate.JPG',width=600,height=200)

# %%
from IPython.display import Image
Image(filename='Bivariate_1.png',width=300,height=300)

# %%
from IPython.display import Image
Image(filename='Multivariate.png',width=500,height=300)

# %%
from IPython.display import Image
Image(filename='Frame Work-EDA.png',width=500,height=300)

# %%
rcParams['figure.figsize']=7,6

# %%
pd.read_csv("k_circle_sales.csv")
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy     249.8            OUT049
# ...

# %%
df_sales=pd.read_csv("k_circle_sales.csv")
df_sales.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy     249.8            OUT049
# 1            Soft Drinks      48.3            OUT018
# 2                   Meat     141.6            OUT049
# 3  Fruits and Vegetables     182.1            OUT010
# 4              Household      53.9            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 2
# 1                       2009      Medium               Tier 2
# ...

# %%
df_sales.shape[0]
# Out:
# 8523

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       6473 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB

# %%
df_sales['Item_Weight'].mean()
# Out:
# 12.857645184135976

# %%
df_sales['Item_Weight'].median()
# Out:
# 12.6

# %%
df_sales['Item_Weight'].mode()
# Out:
# 0    12.15
# Name: Item_Weight, dtype: float64

# %%
#item weight is positively skewed

# %%
sns.distplot(df_sales['Item_Weight'])
plt.title('Item Weight')
plt.show()

# %%
plt.figure(figsize=(10,6))
df_sales.hist()

plt.tight_layout()
plt.show()

# %%
sns.kdeplot(df_sales['Item_Weight'])
plt.show()

# %%
me=df_sales['Item_Weight'].mean()
md=df_sales['Item_Weight'].median()
mo=df_sales['Item_Weight'].mode()[0]     #to take the first mode

# %%
sns.kdeplot(df_sales['Item_Weight']);
plt.axvline(me,label='Mean',color='Red');              #axv means axis vertical line
plt.axvline(md,label='Median',color='Green');
plt.axvline(mo,label='Mode',color='blue');

plt.legend()
plt.show()

# %%
me_vis=df_sales['Item_Visibility'].mean()
md_vis=df_sales['Item_Visibility'].median()
mo_vis=df_sales['Item_Visibility'].mode()[0]

# %%
sns.kdeplot(df_sales['Item_Visibility']);
plt.axvline(me_vis,label='Mean',color='Red');              #axv means axis vertical line
plt.axvline(md_vis,label='Median',color='Green');
plt.axvline(mo_vis,label='Mode',color='blue');

plt.legend()
plt.show()

# %%
df_sales['Item_Weight'].skew()
# Out:
# 0.0824262091221237

# %%
df_sales['Item_Weight'].kurt()
# Out:
# -1.2277664144376634

# %%
sns.distplot(df_sales['Item_Outlet_Sales'])
plt.title('Item_Outlet_Sales')
plt.show()

# %%
me_sales=df_sales['Item_Outlet_Sales'].mean()
md_sales=df_sales['Item_Outlet_Sales'].median()
mo_sales=df_sales['Item_Outlet_Sales'].mode()[0]

# %%
sns.kdeplot(df_sales['Item_Outlet_Sales']);
plt.axvline(me_sales,label='Mean',color='Red');              
plt.axvline(md_sales,label='Median',color='Green');
plt.axvline(mo_sales,label='Mode',color='blue');

plt.legend()
plt.show()

# %%
df_sales['Item_Outlet_Sales'].skew()
# Out:
# 1.1775306028542796

# %%
df_sales['Item_Outlet_Sales'].kurt()
# Out:
# 1.6158766814287264

# %%
df_sales.skew()
# Out:
# Item_Weight                  0.082426
# Item_Visibility              1.167091
# Item_MRP                     0.127390
# Outlet_Establishment_Year   -0.396641
# Item_Outlet_Sales            1.177531
# dtype: float64

# %%
df_sales.kurt()
# Out:
# Item_Weight                 -1.227766
# Item_Visibility              1.679445
# Item_MRP                    -0.887901
# Outlet_Establishment_Year   -1.205694
# Item_Outlet_Sales            1.615877
# dtype: float64

# %%
sns.boxplot(df_sales['Item_Weight']);

# %% [markdown]
# # Day-2:-

# %%
#cummulative plot and its relevance
sns.kdeplot(x='Item_Weight',data=df_sales,cumulative=True);

plt.axvline(20,color='red')               #plotted by us
plt.axhline(0.93,color='orange')          #for analysis

plt.show()

# %%
sns.boxplot(df_sales['Item_Weight'],color='yellow',showmeans=True,orient='h');

# %%
#box plot gives 5 point summary=>max,min,median,quartile 1(left line of yellow square),quartile 3(right line of yellow square)
#green dot is extra due to coding which shows mean
#min and max are also known as distribution points
#q2 is also known as median
#kde do not have sharp edges as it is smoothened version of histogram

# %%
plt.rcParams['figure.figsize']=[11,3]
df_sales.plot(kind='box',color='red')
plt.show()

# %%
#violin plot is combination of box plot and kde

# %%
sns.violinplot(x='Item_Weight',data=df_sales,color='orange');  #to see quartiles type inner='quartiles'
plt.show()

# %%
sns.violinplot(x='Item_Weight',data=df_sales,color='grey')
plt.axvline(df_sales['Item_Weight'].mean(),color='yellow')
plt.axvline(df_sales['Item_Weight'].median(),color='blue')
plt.axvline(df_sales['Item_Weight'].mode()[0],color='red')

# %%
#range
max(df_sales['Item_Outlet_Sales'])-min(df_sales['Item_Outlet_Sales'])
# Out:
# 13053.674799999999

# %%
#standard deviation

df_sales['Item_Outlet_Sales'].std()
# Out:
# 1706.499615733832

# %%
#range and standard deviation both are impacted by outliers.

# %%
#variance

df_sales['Item_Outlet_Sales'].var()
# Out:
# 2912140.938499716

# %%
df_sales.var()
# Out:
# Item_Weight                  2.156169e+01
# Item_Visibility              2.662335e-03
# Item_MRP                     3.876071e+03
# Outlet_Establishment_Year    7.008637e+01
# Item_Outlet_Sales            2.912141e+06
# dtype: float64

# %%
#describe function gives the 5 points summary

df_sales.describe()
# Out:
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.998838                1997.831867
# std       4.643456         0.051598    62.258099                   8.371760
# min       4.555000         0.000000    31.300000                1985.000000
# 25%       8.773750         0.026989    93.800000                1987.000000
# 50%      12.600000         0.053931   142.700000                1999.000000
# 75%      16.850000         0.094585   185.650000                2004.000000
# max      21.350000         0.328391   266.900000                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
#coefficient of variation gives ratio, hence it becomes unitless and it becomes easy to compare
#lower the coefficeint of variation, higher the consistency/performence

# %%
#cov finding

cv_weight=df_sales['Item_Weight'].std()/df_sales['Item_Weight'].mean()

# %%
cv_weight
# Out:
# 0.36114361787767996

# %%
cv_sales=df_sales['Item_Outlet_Sales'].std()/df_sales['Item_Outlet_Sales'].mean()

# %%
cv_sales
# Out:
# 0.7823354371415925

# %%
df_sales.std()/df_sales.mean()
# Out:
# Item_Weight                  0.361144
# Item_Visibility              0.780224
# Item_MRP                     0.441550
# Outlet_Establishment_Year    0.004190
# Item_Outlet_Sales            0.782335
# dtype: float64

# %%
df_sales.cov()
# Out:
#                            Item_Weight  Item_Visibility      Item_MRP  \
# Item_Weight                  21.561688        -0.003172      7.907894
# Item_Visibility              -0.003172         0.002662     -0.005131
# Item_MRP                      7.907894        -0.005131   3876.070885
# Outlet_Establishment_Year    -0.354551        -0.032325      2.629821
# Item_Outlet_Sales           100.560811       -11.325611  60299.006078
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.354551       1.005608e+02
# Item_Visibility                            -0.032325      -1.132561e+01
# Item_MRP                                    2.629821       6.029901e+04
# Outlet_Establishment_Year                  70.086372      -7.019621e+02
# Item_Outlet_Sales                        -701.962133       2.912141e+06

# %%
sns.heatmap(df_sales.cov(),annot=True,cmap='PuBuGn',cbar=False);

# %%
sns.heatmap(df_sales.cov(),mask=np.tril(df_sales.cov()),annot=True,cmap='gnuplot');

# %%
df_sales.corr()
# Out:
#                            Item_Weight  Item_Visibility  Item_MRP  \
# Item_Weight                   1.000000        -0.014048  0.027295
# Item_Visibility              -0.014048         1.000000 -0.001597
# Item_MRP                      0.027295        -0.001597  1.000000
# Outlet_Establishment_Year    -0.011588        -0.074834  0.005046
# Item_Outlet_Sales             0.014123        -0.128625  0.567555
#
#                            Outlet_Establishment_Year  Item_Outlet_Sales
# Item_Weight                                -0.011588           0.014123
# Item_Visibility                            -0.074834          -0.128625
# Item_MRP                                    0.005046           0.567555
# Outlet_Establishment_Year                   1.000000          -0.049135
# Item_Outlet_Sales                          -0.049135           1.000000

# %%
sns.heatmap(df_sales.corr(),mask=np.tril(df_sales.corr()),annot=True,cmap='plasma');

# %%
#multicollinearity:-strong correlation between two independent variables (it leads to havoc(disater)).

# %%
df_sales.select_dtypes('object').columns
# Out:
# Index(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
#        'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'],
#       dtype='object')

# %%
cols=['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
rcParams['figure.figsize']=10,8
j=1
for i in cols:
    plt.subplot(2,3,j)
    sns.countplot(x=df_sales.loc[:,i])
    plt.title(i)
    j=j+1
    
    plt.xticks(rotation=90,fontsize=8)
    
plt.tight_layout()
plt.show()

# %%
df_sales.select_dtypes(include=np.number).columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP',
#        'Outlet_Establishment_Year', 'Item_Outlet_Sales'],
#       dtype='object')

# %%
cols=['Item_Weight','Item_Visibility','Item_MRP']

# %%
rcParams['figure.figsize']=10,8
j=1
for i in cols:
    plt.subplot(2,2,j)
    sns.scatterplot(x=df_sales.loc[:,i],y=df_sales['Item_Outlet_Sales'])
    plt.title(i)
    j=j+1
    
    plt.xticks(rotation=45,fontsize=8)
    
plt.tight_layout()
plt.show()

# %%
sns.pairplot(df_sales,hue='Outlet_Type')

# %%
cols=['Item_Fat_Content', 'Item_Type', 'Outlet_Identifier',
       'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type']

# %%
j=1
for i in cols:
    plt.subplot(2,3,j)
    sns.boxplot(x=df_sales.loc[:,i],y=df_sales['Item_Outlet_Sales'])
    plt.title(i)
    j=j+1
    
    plt.xticks(rotation=90,fontsize=8)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# # Day-3

# %%
df_sales.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
(df_sales.isnull().sum()/df_sales.shape[0]*100)
# Out:
# Item_Identifier               0.000000
# Item_Weight                  17.165317
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Size                  28.276428
# Outlet_Location_Type         24.052564
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
df_sales.isnull().sum().sort_values(ascending=False)
# Out:
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Item_Weight                  1463
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
(df_sales.isnull().sum()/df_sales.shape[0]*100).sort_values(ascending=False)
# Out:
# Outlet_Size                  28.276428
# Outlet_Location_Type         24.052564
# Item_Weight                  17.165317
# Item_Identifier               0.000000
# Item_Fat_Content              0.000000
# Item_Visibility               0.000000
# Item_Type                     0.000000
# Item_MRP                      0.000000
# Outlet_Identifier             0.000000
# Outlet_Establishment_Year     0.000000
# Outlet_Type                   0.000000
# Item_Outlet_Sales             0.000000
# dtype: float64

# %%
df_sales.isnull().sum()[df_sales.isnull().sum()>0]
# Out:
# Item_Weight             1463
# Outlet_Size             2410
# Outlet_Location_Type    2050
# dtype: int64

# %%
#for numerical     (here item weight)

#case 1

df_sales.groupby('Item_Fat_Content')['Item_Weight'].describe()
#if there is missing value in low fat then we will replace it by 12.65 and in regular we can replace by 12.50
# Out:
#                    count       mean       std    min    25%    50%   75%  \
# Item_Fat_Content
# Low Fat           4566.0  12.937387  4.653787  4.590  8.775  12.65  17.1
# Regular           2494.0  12.711654  4.621851  4.555  8.770  12.50  16.7
#
#                     max
# Item_Fat_Content
# Low Fat           21.35
# Regular           21.20

# %%
df_sales['Item_Fat_Content']=df_sales['Item_Fat_Content'].replace('LF','Low Fat').replace('reg','Regular').replace('low fat','Low Fat')

# %%
df_sales['Item_Fat_Content'].value_counts()
# Out:
# Low Fat    5517
# Regular    3006
# Name: Item_Fat_Content, dtype: int64

# %%
#case 2

df_sales.groupby('Item_Type')['Item_Weight'].describe()
# Out:
#                         count       mean       std    min       25%     50%  \
# Item_Type
# Baking Goods            536.0  12.277108  4.773622  4.880   8.23500  11.650
# Breads                  204.0  11.346936  4.440540  4.635   7.12875  10.600
# Breakfast                89.0  12.768202  5.038131  6.425   8.06000  10.695
# Canned                  539.0  12.305705  4.586564  4.615   8.11500  12.150
# Dairy                   566.0  13.426069  4.686532  4.805   9.27750  13.350
# Frozen Foods            718.0  12.867061  4.507383  4.555   8.93500  12.850
# Fruits and Vegetables  1019.0  13.224769  4.575275  5.460   9.19500  13.100
# Hard Drinks             183.0  11.400328  4.239144  4.610   8.26000  10.100
# Health and Hygiene      430.0  13.142314  4.512313  5.175   9.69500  12.150
# Household               759.0  13.384736  4.998845  5.030   8.69500  13.150
# Meat                    337.0  12.817344  4.670812  5.150   9.30000  12.350
# ...

# %%
#case 3

df_sales.groupby('Item_Identifier')['Item_Weight'].describe()
# Out:
#                  count    mean           std     min     25%     50%     75%  \
# Item_Identifier
# DRA12              6.0  11.600  0.000000e+00  11.600  11.600  11.600  11.600
# DRA24              5.0  19.350  0.000000e+00  19.350  19.350  19.350  19.350
# DRA59              6.0   8.270  1.945901e-15   8.270   8.270   8.270   8.270
# DRB01              2.0   7.390  0.000000e+00   7.390   7.390   7.390   7.390
# DRB13              5.0   6.115  0.000000e+00   6.115   6.115   6.115   6.115
# ...                ...     ...           ...     ...     ...     ...     ...
# NCZ30              6.0   6.590  9.729507e-16   6.590   6.590   6.590   6.590
# NCZ41              5.0  19.850  0.000000e+00  19.850  19.850  19.850  19.850
# NCZ42              5.0  10.500  0.000000e+00  10.500  10.500  10.500  10.500
# NCZ53              4.0   9.600  0.000000e+00   9.600   9.600   9.600   9.600
# NCZ54              5.0  14.650  0.000000e+00  14.650  14.650  14.650  14.650
#
#                     max
# ...

# %%
#case 4

df_sales[['Item_Identifier','Item_Weight','Item_Type']][df_sales.Item_Identifier=='FDA15']
# Out:
#      Item_Identifier  Item_Weight Item_Type
# 0              FDA15          9.3     Dairy
# 831            FDA15          9.3     Dairy
# 2599           FDA15          9.3     Dairy
# 2643           FDA15          9.3     Dairy
# 4874           FDA15          9.3     Dairy
# 5413           FDA15          9.3     Dairy
# 6696           FDA15          NaN     Dairy
# 7543           FDA15          9.3     Dairy

# %%
#case 5

df_sales['Item_Weight'].describe()

#this is the most basic case, if we do not find any pattern then replace nulls by median below
# Out:
# count    7060.000000
# mean       12.857645
# std         4.643456
# min         4.555000
# 25%         8.773750
# 50%        12.600000
# 75%        16.850000
# max        21.350000
# Name: Item_Weight, dtype: float64

# %%
df_sales['Item_Weight']=df_sales.groupby('Item_Identifier')['Item_Weight'].transform(lambda x:x.fillna(x.median()))

# %%
df_sales.isnull().sum().sort_values(ascending=False)
# Out:
# Outlet_Size                  2410
# Outlet_Location_Type         2050
# Item_Weight                     4
# Item_Identifier                 0
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
df_sales[df_sales['Item_Weight'].isnull()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927            FDN52          NaN          Regular         0.130933
# 1922           FDK57          NaN          Low Fat         0.079904
# 4187           FDE52          NaN          Regular         0.029742
# 5022           FDQ60          NaN          Regular         0.191501
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927   Frozen Foods      86.9            OUT027                       1985
# 1922   Snack Foods     120.0            OUT027                       1985
# 4187         Dairy      89.0            OUT027                       1985
# 5022  Baking Goods     121.2            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927       Medium               Tier 2  Supermarket Type3          1569.9564
# 1922      Medium               Tier 2  Supermarket Type3          4434.2280
# ...

# %%
#.loc[condition , name of column]. apply function

df_sales.loc[df_sales['Item_Type']=='Frozen Foods','Item_Weight'].median()
# Out:
# 12.85

# %%
#other way for above cell code

df_sales[df_sales['Item_Type']=='Frozen Foods']['Item_Weight'].median()
# Out:
# 12.85

# %%
df_sales.loc[927,'Item_Weight']=12.85

# %%
df_sales.loc[df_sales['Item_Type']=='Snack Foods','Item_Weight'].median()
# Out:
# 13.15

# %%
df_sales.loc[1922,'Item_Weight']=13.15

# %%
df_sales.loc[df_sales['Item_Type']=='Dairy','Item_Weight'].median()
# Out:
# 13.35

# %%
df_sales.loc[4187,'Item_Weight']=13.15

# %%
df_sales.loc[df_sales['Item_Type']=='Baking Goods','Item_Weight'].median()
# Out:
# 11.65

# %%
df_sales.loc[5022,'Item_Weight']=11.65

# %%
df_sales[df_sales['Item_Weight'].isnull()]
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Establishment_Year, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
#for categorigal columns   (here outlet size)

#case 1
df_sales.groupby("Item_Fat_Content")['Outlet_Size'].describe()
# Out:
#                  count unique     top  freq
# Item_Fat_Content
# Low Fat           3955      3  Medium  1799
# Regular           2158      3  Medium   994

# %%
#case 2
df_sales.groupby('Outlet_Type')['Outlet_Size'].describe()     #most appropriate
# Out:
#                   count unique     top  freq
# Outlet_Type
# Grocery Store       528      1   Small   528
# Supermarket Type1  3722      3   Small  1860
# Supermarket Type2   928      1  Medium   928
# Supermarket Type3   935      1  Medium   935

# %%
#case 3
df_sales.groupby('Outlet_Location_Type')['Outlet_Size'].describe()
# Out:
#                      count unique     top  freq
# Outlet_Location_Type
#   -                      0      0     NaN   NaN
#   --                     0      0     NaN   NaN
# ?                        0      0     NaN   NaN
# NAN                      0      0     NaN   NaN
# Tier 2                2793      1  Medium  2793
# Tier 3                 932      1    High   932
# Tier1                 2388      1   Small  2388
# na                       0      0     NaN   NaN

# %%
#case 4
df_sales.groupby(['Outlet_Type','Outlet_Location_Type'])['Outlet_Size'].describe()
# Out:
#                                        count unique     top  freq
# Outlet_Type       Outlet_Location_Type
# Grocery Store       -                      0      0     NaN   NaN
#                     --                     0      0     NaN   NaN
#                   ?                        0      0     NaN   NaN
#                   NAN                      0      0     NaN   NaN
#                   Tier1                  528      1   Small   528
#                   na                       0      0     NaN   NaN
# Supermarket Type1   -                      0      0     NaN   NaN
#                     --                     0      0     NaN   NaN
#                   ?                        0      0     NaN   NaN
#                   NAN                      0      0     NaN   NaN
#                   Tier 2                 930      1  Medium   930
#                   Tier 3                 932      1    High   932
#                   Tier1                 1860      1   Small  1860
# ...

# %%
df_sales['Outlet_Size']=df_sales.groupby('Outlet_Type')['Outlet_Size'].apply(
lambda x: x.fillna(x.mode()[0]))

# %%
#we can replace garbage values by null values and then fill those nulls

df_sales['Outlet_Location_Type'] = df_sales['Outlet_Location_Type'].replace('  -',np.nan).replace('  --',np.nan).replace('?',np.nan).replace('NAN',np.nan).replace('na',np.nan)

# %%
df_sales.Outlet_Location_Type.isnull().sum()
# Out:
# 2410

# %%
#now we can replace these null values as studied above

# %%
#for categorical (here outlet location type)

#case 1

df_sales.groupby('Outlet_Size')['Outlet_Location_Type'].describe()
# Out:
#             count unique     top  freq
# Outlet_Size
# High          932      1  Tier 3   932
# Medium       2793      1  Tier 2  2793
# Small        2388      1   Tier1  2388

# %%
#case 2
df_sales.groupby('Outlet_Type')['Outlet_Location_Type'].describe()
# Out:
#                   count unique     top  freq
# Outlet_Type
# Grocery Store       528      1   Tier1   528
# Supermarket Type1  3722      3   Tier1  1860
# Supermarket Type2   928      1  Tier 2   928
# Supermarket Type3   935      1  Tier 2   935

# %%
#case 3
df_sales.groupby(['Outlet_Size','Outlet_Type'])['Outlet_Location_Type'].describe()
# Out:
#                               count unique     top  freq
# Outlet_Size Outlet_Type
# High        Supermarket Type1   932      1  Tier 3   932
# Medium      Supermarket Type1   930      1  Tier 2   930
#             Supermarket Type2   928      1  Tier 2   928
#             Supermarket Type3   935      1  Tier 2   935
# Small       Grocery Store       528      1   Tier1   528
#             Supermarket Type1  1860      1   Tier1  1860

# %%
df_sales['Outlet_Location_Type']= df_sales.groupby(["Outlet_Size","Outlet_Type"])['Outlet_Location_Type'].apply(
    lambda x : x.fillna(x.mode()[0]))

# %%
df_sales.Outlet_Location_Type.isnull().sum()
# Out:
# 0

# %%
df_sales.isnull().sum()
# Out:
# Item_Identifier              0
# Item_Weight                  0
# Item_Fat_Content             0
# Item_Visibility              0
# Item_Type                    0
# Item_MRP                     0
# Outlet_Identifier            0
# Outlet_Establishment_Year    0
# Outlet_Size                  0
# Outlet_Location_Type         0
# Outlet_Type                  0
# Item_Outlet_Sales            0
# dtype: int64

# %% [markdown]
# # Day 4

# %%
df_sales['Item_Outlet_Sales'].describe()
# Out:
# count     8523.000000
# mean      2181.288914
# std       1706.499616
# min         33.290000
# 25%        834.247400
# 50%       1794.331000
# 75%       3101.296400
# max      13086.964800
# Name: Item_Outlet_Sales, dtype: float64

# %%
q1=df_sales['Item_Outlet_Sales'].quantile(0.25)
q2=df_sales['Item_Outlet_Sales'].quantile(0.50)
q3=df_sales['Item_Outlet_Sales'].quantile(0.75)

# %%
iqr=q3-q1
iqr
# Out:
# 2267.049

# %%
df_sales.drop('Outlet_Establishment_Year',axis=1,inplace=True)

# %%
num_cols=df_sales.select_dtypes(include=np.number)
num_cols.columns
# Out:
# Index(['Item_Weight', 'Item_Visibility', 'Item_MRP', 'Item_Outlet_Sales'], dtype='object')

# %%
fig, axs=plt.subplots(2,2,figsize=(25,15))       #figsize goes in fig and plt.subplot(2,2) goes in ax
for i,j in zip(num_cols,axs.flatten()):          #we can do them seperately also.
    sns.boxplot(df_sales[i],ax=j)               #its similar to yestaerday's j=1 code.
    plt.title(i)                                #google=>fig gives us canvas and axs is iterable,i.e.,axs have 4 values(plots)
                                                #ax in box plot means axis(which subplot)
plt.tight_layout()
plt.show()

# %%
#axis=0 or 1 is opposite in dataframes and np.arrays

# %%
lower_limit=q1-(1.5*iqr)
upper_limit=q3+(1.5*iqr)

# %%
df_sales_num=df_sales.select_dtypes(include=np.number)      #as box plot only works on numerical columns

# %%
df_rem_out=df_sales[~((df_sales_num<(lower_limit)) | (df_sales_num> (upper_limit))).any(axis=1)]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier Outlet_Size  \
# 0                     Dairy     249.8            OUT049      Medium
# ...

# %%
#scaling

# %%
#standard scalars are use when distribution is normal else use min max scalars
#standard range is -3 to 3 and for min max range is 0 to 1

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

# %%
sc=StandardScaler()
mm=MinMaxScaler()

# %%
sc.fit_transform(df_sales_num)
# Out:
# array([[-0.7662174 , -0.97073217,  1.74768499,  0.910601  ],
#        [-1.49417499, -0.90811123, -1.48903161, -1.01844035],
#        [ 0.99983356, -0.95691733,  0.00965652, -0.04923754],
#        ...,
#        [-0.48623371, -0.59978449, -0.89790917, -0.57909963],
#        [-1.21634502,  1.53287976, -0.6087732 , -0.19672492],
#        [ 0.41832897, -0.41193591, -1.05211502, -0.82959407]])

# %%
#by scalar
df_scaled_sc=pd.DataFrame(sc.fit_transform(df_sales_num),columns=df_sales_num.columns)

# %%
df_scaled_sc.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0    -0.766217        -0.970732  1.747685           0.910601
# 1    -1.494175        -0.908111 -1.489032          -1.018440
# 2     0.999834        -0.956917  0.009657          -0.049238
# 3     1.365966        -1.281758  0.660212          -0.849103
# 4    -0.845905        -1.281758 -1.399078          -0.695373

# %%
#by min max
df_scaled_mm=pd.DataFrame(mm.fit_transform(df_sales_num),columns=df_sales_num.columns)

# %%
df_scaled_mm.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0     0.282525         0.048866  0.927419           0.283587
# 1     0.081274         0.058705  0.072156           0.031419
# 2     0.770765         0.051037  0.468166           0.158115
# 3     0.871986         0.000000  0.640068           0.053555
# 4     0.260494         0.000000  0.095925           0.073651

# %%
#scaling are impacted by outliers

# %%
df_sales_copy=df_sales.copy()

# %%
num_copy=df_sales_copy.select_dtypes(np.number)

# %%
df_scaled_copy=pd.DataFrame(sc.fit_transform(num_copy),columns=num_copy.columns)
df_scaled_copy.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales
# 0    -0.766217        -0.970732  1.747685           0.910601
# 1    -1.494175        -0.908111 -1.489032          -1.018440
# 2     0.999834        -0.956917  0.009657          -0.049238
# 3     1.365966        -1.281758  0.660212          -0.849103
# 4    -0.845905        -1.281758 -1.399078          -0.695373

# %%
df_sales_copy_num=df_sales_copy.select_dtypes(include=np.number)

# %%
m_zscore=df_sales_copy[~((df_sales_copy_num<(-3)) | (df_sales_copy_num>(3))).any(axis=1)]
m_zscore.head()
# Out:
# Empty DataFrame
# Columns: [Item_Identifier, Item_Weight, Item_Fat_Content, Item_Visibility, Item_Type, Item_MRP, Outlet_Identifier, Outlet_Size, Outlet_Location_Type, Outlet_Type, Item_Outlet_Sales]
# Index: []

# %%
#in scaling skewness and kurtosis do not change but in square root transformation, skewness and kurtosis will be affected 
#i,e, shape remains same in scaling and changes in sq root transformation

# %%
#transformation reduces skewness which helps in making a better pattern.
